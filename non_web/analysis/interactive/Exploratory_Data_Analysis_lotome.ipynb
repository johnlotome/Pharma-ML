# %%
import pandas as pd
import numpy as np 
import statsmodels.api as sm
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('bmh')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## LOADING DATASET INTO COLAB

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
store = pd.read_csv('/content/gdrive/My Drive/kaggle/rossmann-store-sales/store.csv')
test = pd.read_csv('/content/gdrive/My Drive/kaggle/rossmann-store-sales/test.csv')
train = pd.read_csv('/content/gdrive/My Drive/kaggle/rossmann-store-sales/train.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### DATA CLEANING/WRANGLING

# %%
store.head(3)
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
#
# [3 rows x 10 columns]

# %%
train.tail(3)
# Out:
#          Store  DayOfWeek        Date  ...  Promo  StateHoliday  SchoolHoliday
# 1017206   1113          2  2013-01-01  ...      0             a              1
# 1017207   1114          2  2013-01-01  ...      0             a              1
# 1017208   1115          2  2013-01-01  ...      0             a              1
#
# [3 rows x 9 columns]

# %%
test.tail(3)
# Out:
#           Id  Store  DayOfWeek  ... Promo  StateHoliday  SchoolHoliday
# 41085  41086   1113          6  ...     0             0              0
# 41086  41087   1114          6  ...     0             0              0
# 41087  41088   1115          6  ...     0             0              1
#
# [3 rows x 8 columns]

# %%
print(store.shape)
print(train.shape)
print(test.shape)
# Out:
# (1115, 10)
# (1017209, 9)
# (41088, 8)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store.duplicated().any()
# Out:
# False

# %%
store.isna().any()
# Out:
# Store                        False
# StoreType                    False
# Assortment                   False
# CompetitionDistance           True
# CompetitionOpenSinceMonth     True
# CompetitionOpenSinceYear      True
# Promo2                       False
# Promo2SinceWeek               True
# Promo2SinceYear               True
# PromoInterval                 True
# dtype: bool

# %%
store.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
test.duplicated().any()
# Out:
# False

# %%
test.isna().any()
# Out:
# Id               False
# Store            False
# DayOfWeek        False
# Date             False
# Open              True
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %%
test.isna().sum()
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %%
train.duplicated().any()
# Out:
# False

# %%
train.isna().any()
# Out:
# Store            False
# DayOfWeek        False
# Date             False
# Sales            False
# Customers        False
# Open             False
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %% [markdown]
# #### CHECKING OUTLIERS

# %%
def outlier_vars(data, show_plot=True):
    
    """
    This functions checks for columns with outlers using the IQR method
    
    It accespts as argmuent a dataset. 
    show_plot can be set to True to output pairplots of outlier columns
    
    """
    
    outliers = []
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    num_data = data.select_dtypes(include='number')
    result = dict ((((num_data < (Q1 - 1.5 * IQR)) | (num_data > (Q3 + 1.5 * IQR)))==True).any())
    for k,v in result.items():
        if v == True:
            outliers.append(k)
    if show_plot:
        pair_plot = sns.pairplot(data[outliers]);
        print(f'{result},\n\n Visualization of outlier columns')
        return pair_plot
    else:
        return data[outliers]

# %%
outlier_vars(store)
# Out:
# {'Store': False, 'CompetitionDistance': True, 'CompetitionOpenSinceMonth': False, 'CompetitionOpenSinceYear': True, 'Promo2': False, 'Promo2SinceWeek': False, 'Promo2SinceYear': False},
#
#  Visualization of outlier columns

# %%
outlier_vars(train)
# Out:
# {'Store': False, 'DayOfWeek': False, 'Sales': True, 'Customers': True, 'Open': True, 'Promo': False, 'SchoolHoliday': True},
#
#  Visualization of outlier columns

# %%
outlier_vars(test)
# Out:
# {'Id': False, 'Store': False, 'DayOfWeek': False, 'Open': True, 'Promo': False, 'SchoolHoliday': False},
#
#  Visualization of outlier columns

# %% [markdown]
# #### DATA PREPROCESSING

# %%
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  ...  Open  Promo  StateHoliday SchoolHoliday
# 0      1          5  2015-07-31   5263  ...     1      1             0             1
# 1      2          5  2015-07-31   6064  ...     1      1             0             1
# 2      3          5  2015-07-31   8314  ...     1      1             0             1
# 3      4          5  2015-07-31  13995  ...     1      1             0             1
# 4      5          5  2015-07-31   4822  ...     1      1             0             1
#
# [5 rows x 9 columns]

# %%
## Converting categorical columns in train set into object
train_cols = ['DayOfWeek','Open','Promo','StateHoliday','SchoolHoliday']
for i in train_cols:
    train = train.astype({i:'object'})

## Converting the date column to the datetime format
train['Date'] = pd.to_datetime(train.Date)

# %%
## Converting categorical columns in test set into object
for i in train_cols:
    test = test.astype({i:'object'})

## Converting the date column to datetime format 
test['Date'] = pd.to_datetime(test.Date)

# %%
## Converting categorical columns in store set into object
store_cols = ['StoreType','Assortment','CompetitionOpenSinceMonth','Promo2']
for i in store_cols:
    store = store.astype({i:'object'})

# %%
## Dealing with cardinality
train['StateHoliday'].replace({0:'o','0':'o'},inplace=True)
test['StateHoliday'].replace({'0':'o'},inplace=True)

# %% [markdown]
# ### TIME SERIES ANALYSIS

# %% [markdown]
# #### MERGING STORE AND TRAIN DATASET

# %%
store_train = pd.merge(store, train, on='Store')

# %%
store_train.dtypes
# Out:
# Store                                 int64
# StoreType                            object
# Assortment                           object
# CompetitionDistance                 float64
# CompetitionOpenSinceMonth            object
# CompetitionOpenSinceYear            float64
# Promo2                               object
# Promo2SinceWeek                     float64
# Promo2SinceYear                     float64
# PromoInterval                        object
# DayOfWeek                            object
# Date                         datetime64[ns]
# Sales                                 int64
# Customers                             int64
# Open                                 object
# Promo                                object
# StateHoliday                         object
# SchoolHoliday                        object
# dtype: object

# %%
store_train.describe(include='object')
# Out:
#        StoreType Assortment  ...  StateHoliday  SchoolHoliday
# count    1017209    1017209  ...       1017209        1017209
# unique         4          3  ...             4              2
# top            a          a  ...             o              0
# freq      551627     537445  ...        986159         835488
#
# [4 rows x 10 columns]

# %%
store_train.shape
# Out:
# (1017209, 18)

# %% [markdown]
# #### TRENDS AND SEASONALITY ANALYSIs

# %%
sales = store_train.groupby("Date")["Sales"].sum().reset_index()
sales
# Out:
#           Date     Sales
# 0   2013-01-01     97235
# 1   2013-01-02   6949829
# 2   2013-01-03   6347820
# 3   2013-01-04   6638954
# 4   2013-01-05   5951593
# ..         ...       ...
# 937 2015-07-27  10707292
# 938 2015-07-28   9115073
# 939 2015-07-29   8499962
# 940 2015-07-30   8798854
# 941 2015-07-31  10109742
#
# [942 rows x 2 columns]

# %%
sales['datetime'] = pd.to_datetime(sales['Date'])
sales = sales.set_index('datetime')
sales.drop(['Date'], axis=1, inplace=True)
sales.head()
# Out:
#               Sales
# datetime
# 2013-01-01    97235
# 2013-01-02  6949829
# 2013-01-03  6347820
# 2013-01-04  6638954
# 2013-01-05  5951593

# %% [markdown]
# ##### DAILY TRENDS

# %%
y = sales["Sales"].resample("D").mean()
plt.title("Daily trends")
y.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# ##### WEEKLY TRENDS

# %%
y = sales["Sales"].resample("W").mean()
plt.title("Weekly Trends")
y.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# ##### MONTHLY TRENDS

# %%
y = sales["Sales"].resample("MS").mean()
y.plot(figsize=(15, 6))
plt.title("Monthly Trends")
plt.show()

# %% [markdown]
# ##### TRENDS COMPONENTS

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# #### CORRELATION OF CUSTOMERS AND SALES

# %%
x = store_train["Customers"]
y = store_train["Sales"]

matplotlib.style.use("ggplot")
plt.figure(figsize=(10,6))
plt.title("A correlation of Sales and Number of Customers")
plt.scatter(x, y)
plt.xlabel("Number of Customers")
plt.ylabel("Number of sales")
plt.show()

# %%
sns.lineplot(x,y)
plt.show()

# %% [markdown]
# #### SALES TRENDS

# %%
store_train.groupby("StoreType")['Sales'].describe()
# Out:
#               count          mean          std  ...     50%       75%      max
# StoreType                                       ...
# a          551627.0   5738.179710  3964.028134  ...  5618.0   7860.00  41551.0
# b           15830.0  10058.837334  5280.525506  ...  9025.5  13082.75  38722.0
# c          136840.0   5723.629246  3721.700886  ...  5766.0   7849.00  31448.0
# d          312912.0   5641.819243  3473.393781  ...  5826.0   7691.00  38037.0
#
# [4 rows x 8 columns]

# %%
store_train.groupby("StoreType")['Sales', 'Customers'].sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 Sales  Customers
# StoreType
# a          3165334859  363541434
# b           159231395   31465621
# c           783221426   92129705
# d          1765392943  156904995

# %%
store_train['Year'] = pd.DatetimeIndex(store_train['Date']).year
store_train['Month'] = pd.DatetimeIndex(store_train['Date']).month
store_train['Day'] = pd.DatetimeIndex(store_train['Date']).day
store_train['WeekOfYear'] = pd.DatetimeIndex(store_train['Date']).weekofyear

# %%
sns.factorplot(data = store_train, x='Month', y='Sales',
               col='StoreType', 
               palette = "plasma",
               hue="StoreType",
               row = 'Promo',
               color='#386B7F')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(data = store_train, x='Month', y='Customers',
               col='StoreType', 
               palette = "plasma",
               hue="StoreType",
               row = 'Promo',
               color='#386B7F')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
store_train['SalePerCustomer'] = store_train['Sales']/store_train['Customers']

sns.factorplot(data = store_train, x='Month', y='SalePerCustomer',
               col='StoreType', 
               palette = "plasma",
               hue="StoreType",
               row = 'Promo',
               color='#386B7F')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(data = store_train, x='Month', y='Sales',
               col='DayOfWeek', 
               palette = "plasma",
               hue="StoreType",
               row = 'StoreType',
               color='#386B7F')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ##### EFFECTS OF ASSORTMENT ON SALES TREND

# %%
store_train.groupby('Assortment')['Sales', 'Customers'].sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                  Sales  Customers
# Assortment
# a           2945750070  332766938
# b             70946312   16972525
# c           2856484241  294302292

# %%
sns.factorplot(data = store_train, x='Month', y='Sales',
               col='Assortment', 
               palette = "plasma",
               hue="Assortment",
               
               color='#386B7F')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ##### Trends of customer behavior during store open and closing times

# %%
sns.factorplot(data = store_train, x='Month', y='Sales',
               col='Open', 
               palette = "plasma",
               hue="Open",
               
               color='#386B7F')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ##### Trends in stores that are open all weekday

# %%
stores_all_weekday  = store_train[(store_train.Open == 1) & (store_train.DayOfWeek == 7)]
sns.factorplot(data = stores_all_weekday, x='Month', y='Sales',
               col="StoreType", 
               palette = "plasma",
               hue="StoreType",
               
               color='#386B7F')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
